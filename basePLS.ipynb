# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

import commonutils
import models
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.inspection import permutation_importance

from dataclasses import dataclass
import prettyprinter as pp

from sklearn.cross_decomposition import PLSRegression
import warnings
import sys

from sklearn import preprocessing

from copy import deepcopy

# %%
@dataclass
class ModelResults:
    # model related data
    plsmodel = None
    # predicted values
    y_pred: list = None
    y_pred_bestourmethod: list = None
    y_pred_bestinsidemethod: list = None
    # data related to full set
    fulldescriptors: list = None
    labels: list = None
    top_correlation: list = None
    # data realated to inside and our methods
    inside_methods_rmse: list = None
    bestinsidemethod_rmse: float = 0.0
    bestinsidemethod: str = None
    inside_methods_r2: list = None
    our_methods_rmse: dict = None
    bestourmethod_rmse: float = 0.0
    bestourmethod: str = None
    our_methods_r2: dict = None
    our_methods_name : list = None

def read_and_init (inrootdir, supersetnames, howmanydifs, methods, \
                   DEBUG=False):
    
    allvalues_perset = {}
    fullsetnames = []
    models_results = {}

    toberemoved = {}
    for super_setname in supersetnames:
        toberemoved[super_setname] = []
        allvalues_perset[super_setname] = []
        fullsetnames.append(super_setname)
        for i, setname in enumerate(supersetnames[super_setname]):
              print("Reading dataset: ", setname)
              rootdir = inrootdir + super_setname + "/" +setname
              labelsfilename = inrootdir + setname +"_labels.txt"
        
              values =\
                    commonutils.read_dataset(rootdir, labelsfilename, \
                                             howmanydifs, methods, \
                                             debug=DEBUG)
              
              if (values is None) or (len(values) <= 2):
                    print(setname + " No data found for this dataset")
                    print("")
                    toberemoved[super_setname].append(i)
              else:
                    fullsetname = super_setname+"_"+setname
                    fullsetnames.append(fullsetname)
                    allvalues_perset[fullsetname] = values  
                    print("Number of samples: ", len(allvalues_perset[fullsetname]))
                    print("Number of basic descriptors: ", len(allvalues_perset[fullsetname]))

                    allvalues_perset[super_setname] += allvalues_perset[fullsetname]
                    print("")

    for super_setname in toberemoved:
        for i in sorted(toberemoved[super_setname], reverse=True):
          del supersetnames[super_setname][i]
 
    allvalues_perset["Full"] = []
    for super_setname in supersetnames:
          allvalues_perset["Full"] += allvalues_perset[super_setname]  
    fullsetnames.append("Full")

    for setname in fullsetnames:
        models_results[setname] = ModelResults()

    return allvalues_perset, fullsetnames, models_results

# %%
warnings.simplefilter("ignore")
CORRCUT = 0.98

supersetnames = {"BARRIER" : \
                       ["BH76","BHDIV10","BHPERI",\
                        "BHROT27","INV24","PX13","WCPT18"] \
                    ,"INTRA" : \
                       ["ACONF",'Amino20x4',"BUT14DIOL",\
                        "ICONF","IDISP","MCONF",\
                        "PCONF21","SCONF","UPU23"] , \
                    "SMALL" :\
                        ["AL2X6","ALK8","ALKBDE10","BH76RC",\
                         "DC13","DIPCS10","FH51","G21EA",\
                         "G21IP","G2RC","HEAVYSB11","NBPRC",\
                         "PA26","RC21","SIE4x4","TAUT15",\
                         "W4-11","YBDE18"], \
                    "INTER" :\
                       ["ADIM6","AHB21","CARBHB12",\
                        "CHB6","HAL59","HEAVY28","IL16",\
                        "PNICO23","RG18","S22","S66","WATER27"] , \
                    "LARGE" :\
                        ["BSR36","C60ISO","CDIE20","DARC",\
                         "ISO34","ISOL24","MB16-43","PArel",\
                            "RSE43"]}           

howmanydifs = 3
insidemethodslist = ['W','D3(0)','D3(BJ)']
energy_decomp_terms = ["Nuclear Repulsion  :","One Electron Energy:",\
                       "Two Electron Energy:","Potential Energy   :",\
                        "Kinetic Energy     :","E(X)               :",\
                        "E(C)               :","Dispersion correction",\
                        "FINAL SINGLE POINT ENERGY"]

energy_decomp_terms = ["FINAL SINGLE POINT ENERGY"]

methods_keys = ["PBE-MINIX","PBE-SVP","PBE-TZVP",\
                "PBE0-MINIX","PBE0-SVP","PBE0-TZVP",\
                "TPSS-MINIX","TPSS-SVP","TPSS-TZVP",\
                "TPSSh-MINIX","TPSSh-SVP","TPSSh-TZVP"]

methods_keys = ["PBE-MINIX"]     # This line allows to define the 
                                            # the functional-basis set data to use
                                            # in the calculations

methods = {key: energy_decomp_terms for key in methods_keys}

# read all the data and initialize the data structures
rootdir = "../Datasets/FullDataSet/"  
allvalues_perset, fullsetnames, models_results = \
        read_and_init (rootdir, supersetnames, howmanydifs, methods, \
                       DEBUG=True)
# Out:
# Reading dataset:  BH76
# Number of samples:  76
# Number of basic descriptors:  76
#
# Reading dataset:  BHDIV10
# Number of samples:  10
# Number of basic descriptors:  10
#
# Reading dataset:  BHPERI
# Number of samples:  26
# Number of basic descriptors:  26
#
# Reading dataset:  BHROT27
# Number of samples:  27
# Number of basic descriptors:  27
#
# Reading dataset:  INV24
# Number of samples:  24
# Number of basic descriptors:  24
#
# Reading dataset:  PX13
# Number of samples:  13
# Number of basic descriptors:  13
#
# Reading dataset:  WCPT18
# Number of samples:  18
# Number of basic descriptors:  18
#
# Reading dataset:  ACONF
# Number of samples:  15
# Number of basic descriptors:  15
#
# Reading dataset:  Amino20x4
# Number of samples:  80
# Number of basic descriptors:  80
#
# Reading dataset:  BUT14DIOL
# Number of samples:  64
# Number of basic descriptors:  64
#
# Reading dataset:  ICONF
# Number of samples:  17
# Number of basic descriptors:  17
#
# Reading dataset:  IDISP
# Number of samples:  6
# Number of basic descriptors:  6
#
# Reading dataset:  MCONF
# Number of samples:  51
# Number of basic descriptors:  51
#
# Reading dataset:  PCONF21
# Number of samples:  18
# Number of basic descriptors:  18
#
# Reading dataset:  SCONF
# Number of samples:  17
# Number of basic descriptors:  17
#
# Reading dataset:  UPU23
# Number of samples:  23
# Number of basic descriptors:  23
#
# Reading dataset:  AL2X6
# Number of samples:  6
# Number of basic descriptors:  6
#
# Reading dataset:  ALK8
# Number of samples:  8
# Number of basic descriptors:  8
#
# Reading dataset:  ALKBDE10
# Number of samples:  10
# Number of basic descriptors:  10
#
# Reading dataset:  BH76RC
# Number of samples:  30
# Number of basic descriptors:  30
#
# Reading dataset:  DC13
# Number of samples:  13
# Number of basic descriptors:  13
#
# Reading dataset:  DIPCS10
# Number of samples:  10
# Number of basic descriptors:  10
#
# Reading dataset:  FH51
# Number of samples:  51
# Number of basic descriptors:  51
#
# Reading dataset:  G21EA
# Number of samples:  25
# Number of basic descriptors:  25
#
# Reading dataset:  G21IP
# Number of samples:  36
# Number of basic descriptors:  36
#
# Reading dataset:  G2RC
# Number of samples:  25
# Number of basic descriptors:  25
#
# Reading dataset:  HEAVYSB11
# Number of samples:  11
# Number of basic descriptors:  11
#
# Reading dataset:  NBPRC
# Number of samples:  12
# Number of basic descriptors:  12
#
# Reading dataset:  PA26
# Number of samples:  26
# Number of basic descriptors:  26
#
# Reading dataset:  RC21
# Number of samples:  21
# Number of basic descriptors:  21
#
# Reading dataset:  SIE4x4
# Number of samples:  16
# Number of basic descriptors:  16
#
# Reading dataset:  TAUT15
# Number of samples:  15
# Number of basic descriptors:  15
#
# Reading dataset:  W4-11
# Number of samples:  140
# Number of basic descriptors:  140
#
# Reading dataset:  YBDE18
# Number of samples:  18
# Number of basic descriptors:  18
#
# Reading dataset:  ADIM6
# Number of samples:  6
# Number of basic descriptors:  6
#
# Reading dataset:  AHB21
# Number of samples:  21
# Number of basic descriptors:  21
#
# Reading dataset:  CARBHB12
# Number of samples:  12
# Number of basic descriptors:  12
#
# Reading dataset:  CHB6
# Number of samples:  6
# Number of basic descriptors:  6
#
# Reading dataset:  HAL59
# Number of samples:  59
# Number of basic descriptors:  59
#
# Reading dataset:  HEAVY28
# Number of samples:  28
# Number of basic descriptors:  28
#
# Reading dataset:  IL16
# Number of samples:  16
# Number of basic descriptors:  16
#
# Reading dataset:  PNICO23
# Number of samples:  23
# Number of basic descriptors:  23
#
# Reading dataset:  RG18
# Number of samples:  18
# Number of basic descriptors:  18
#
# Reading dataset:  S22
# Number of samples:  22
# Number of basic descriptors:  22
#
# Reading dataset:  S66
# Number of samples:  66
# Number of basic descriptors:  66
#
# Reading dataset:  WATER27
# Number of samples:  27
# Number of basic descriptors:  27
#
# Reading dataset:  BSR36
# Number of samples:  36
# Number of basic descriptors:  36
#
# Reading dataset:  C60ISO
# Number of samples:  9
# Number of basic descriptors:  9
#
# Reading dataset:  CDIE20
# Number of samples:  20
# Number of basic descriptors:  20
#
# Reading dataset:  DARC
# Number of samples:  14
# Number of basic descriptors:  14
#
# Reading dataset:  ISO34
# Number of samples:  34
# Number of basic descriptors:  34
#
# Reading dataset:  ISOL24
# Number of samples:  24
# Number of basic descriptors:  24
#
# Reading dataset:  MB16-43
# Number of samples:  43
# Number of basic descriptors:  43
#
# Reading dataset:  PArel
# Number of samples:  20
# Number of basic descriptors:  20
#
# Reading dataset:  RSE43
# Number of samples:  43
# Number of basic descriptors:  43

# %%
# WTMAD_lf calc 
# Test with initial dictionary

# Creating the list to feed the WTMAD calc:

fullandsupersets = ["Full","SMALL","LARGE","BARRIER","INTER","INTRA"]
datasets = [dataset for sublist in supersetnames.values() for dataset in sublist]

id_list = []
lab_list = []
pred_list = [] # To test the function, calculations using PBE-MINIX are being used

for setname in fullsetnames:
    if setname not in fullandsupersets:
        for val in allvalues_perset[setname]:
            identifier = setname+'_'+str(val['chemicals'])
            id_list.append(identifier)
            lab_list.append(val['label'])
            pred_list.append(val['PBE-MINIX_energydiff']["PBE-MINIX_FINAL_SINGLE_POINT_ENERGY"])
            #pred_list.append(val['label']+val['difs'][2]) #This line allowed to test the WTMAD-2 calculation by operating over reference data


from commonutils import wtmad2_lf

# WTMAD2 calculation for reference values just as example:

wtmad2 = wtmad2_lf(id_list,lab_list,pred_list,fullandsupersets,datasets)

print(wtmad2)
# Out:
#        Set  WTMAD-2
# 0    SMALL    61.17
# 1    LARGE    43.15
# 2  BARRIER    24.64
# 3    INTER    20.81
# 4    INTRA     5.39
# 5     Full    45.90

# %%
for val in allvalues_perset:
    print("======= START =======")
    print(val, len(allvalues_perset[val]))
    pp.pprint(allvalues_perset[val])
    print("=======  END  =======")
# Out:
# ======= START =======
# BARRIER 194
# [
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['h', 'n2o', 'n2ohts'],
#         'label': 17.7,
#         'difs': [-7.55, -7.74, -7.96],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -11.632145586501455
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['oh', 'n2', 'n2ohts'],
#         'label': 82.6,
#         'difs': [-30.06, -30.31, -30.75],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 61.015986088566265
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['h', 'hf', 'hfhts'],
#         'label': 42.1,
#         'difs': [-13.79, -13.84, -13.92],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 19.52816423405176
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['hf', 'h', 'hfhts'],
#         'label': 42.1,
#         'difs': [-13.79, -13.84, -13.92],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 19.52816423405176
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['h', 'hcl', 'hclhts'],
#         'label': 17.8,
#         'difs': [-8.0, -8.05, -8.24],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 2.903266357833582
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['hcl', 'h', 'hclhts'],
#         'label': 17.8,
#         'difs': [-8.0, -8.05, -8.24],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 2.903266357833582
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['h', 'ch3f', 'hfch3ts'],
#         'label': 30.5,
#         'difs': [-11.76, -12.06, -11.99],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 1.3860960805005953
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['hf', 'ch3', 'hfch3ts'],
#         'label': 56.9,
#         'difs': [-15.55, -16.06, -15.99],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 25.577846782329562
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['h', 'f2', 'hf2ts'],
#         'label': 1.5,
#         'difs': [-10.82, -10.94, -10.98],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -19.567899866822966
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['hf', 'f', 'hf2ts'],
#         'label': 104.8,
#         'difs': [-25.04, -25.16, -25.23],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 48.73726589401325
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['ch3', 'clf', 'ch3fclts'],
#         'label': 7.1,
#         'difs': [-12.49, -13.23, -13.13],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -18.854300611162724
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['ch3f', 'cl', 'ch3fclts'],
#         'label': 59.8,
#         'difs': [-18.32, -18.86, -18.93],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 24.035980343532152
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['f-', 'ch3f', 'fch3fts'],
#         'label': -0.6,
#         'difs': [-9.99, -10.46, -10.4],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -83.96207068600646
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['ch3f', 'f-', 'fch3fts'],
#         'label': -0.6,
#         'difs': [-9.99, -10.46, -10.4],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -83.96207068600646
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['fch3fcomp', 'fch3fts'],
#         'label': 13.4,
#         'difs': [-7.24, -7.1, -7.27],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -36.953182442128266
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['fch3fcomp', 'fch3fts'],
#         'label': 13.4,
#         'difs': [-7.24, -7.1, -7.27],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -36.953182442128266
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['cl-', 'ch3cl', 'clch3clts'],
#         'label': 2.5,
#         'difs': [-7.29, -8.06, -8.25],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -24.625240302297193
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['ch3cl', 'cl-', 'clch3clts'],
#         'label': 2.5,
#         'difs': [-7.29, -8.06, -8.25],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -24.625240302297193
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['clch3clcomp', 'clch3clts'],
#         'label': 13.5,
#         'difs': [-6.8, -6.77, -7.0],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -8.198647978549067
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['clch3clcomp', 'clch3clts'],
#         'label': 13.5,
#         'difs': [-6.8, -6.77, -7.0],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -8.198647978549067
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['f-', 'ch3cl', 'fch3clts'],
#         'label': -12.3,
#         'difs': [-9.62, -10.24, -10.06],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -110.61418277714479
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['cl-', 'ch3f', 'fch3clts'],
#         'label': 19.8,
#         'difs': [-7.69, -8.35, -8.69],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 17.672695219429627
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['fch3clcomp1', 'fch3clts'],
#         'label': 3.5,
#         'difs': [-4.96, -4.92, -4.99],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -32.883194754831564
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['fch3clcomp2', 'fch3clts'],
#         'label': 29.6,
#         'difs': [-7.87, -7.79, -8.17],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 28.717516680315395
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['oh-', 'ch3f', 'hoch3fts'],
#         'label': -2.7,
#         'difs': [-11.1, -11.72, -11.81],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -69.75955383556698
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['ch3oh', 'f-', 'hoch3fts'],
#         'label': 17.6,
#         'difs': [-10.29, -10.82, -10.72],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -65.97951176310768
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['hoch3fcomp2', 'hoch3fts'],
#         'label': 11.0,
#         'difs': [-9.18, -9.15, -9.37],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -42.78603387593789
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['hoch3fcomp1', 'hoch3fts'],
#         'label': 47.7,
#         'difs': [-4.1, -4.23, -4.11],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 37.170232229914305
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['h', 'n2', 'hn2ts'],
#         'label': 14.6,
#         'difs': [-9.39, -9.44, -9.71],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -17.715224603368366
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['hn2', 'hn2ts'],
#         'label': 10.9,
#         'difs': [-1.89, -1.92, -1.98],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 26.142121701858038
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['h', 'co', 'hcots'],
#         'label': 3.2,
#         'difs': [-4.95, -5.16, -5.31],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -12.95852300454358
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['hco', 'hcots'],
#         'label': 22.8,
#         'difs': [1.62, 1.47, 1.44],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 48.57666306471283
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['h', 'c2h4', 'c2h5ts'],
#         'label': 2.0,
#         'difs': [-2.13, -2.49, -2.7],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -3.0226611244089017
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['c2h5', 'c2h5ts'],
#         'label': 42.0,
#         'difs': [-1.73, -1.94, -2.01],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 62.51327377798418
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['ch3', 'c2h4', 'c3h7ts'],
#         'label': 6.4,
#         'difs': [-4.79, -5.96, -6.31],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -5.402265037299779
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['c3h7', 'c3h7ts'],
#         'label': 33.0,
#         'difs': [-3.31, -3.53, -3.42],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 38.40923527602793
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['hcn', 'hcnts'],
#         'label': 48.1,
#         'difs': [-2.46, -2.42, -2.46],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 72.05159129395312
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['hnc', 'hcnts'],
#         'label': 33.0,
#         'difs': [-2.33, -2.3, -2.27],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 52.31890417552656
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['h', 'hcl', 'RKT01'],
#         'label': 6.1,
#         'difs': [-5.55, -5.63, -5.8],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -20.51882912602566
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['H2', 'cl', 'RKT01'],
#         'label': 8.0,
#         'difs': [-9.15, -9.23, -9.54],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 2.9221086020547222
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['oh', 'H2', 'RKT02'],
#         'label': 5.2,
#         'difs': [-11.19, -11.33, -11.49],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 0.19753147981024058
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['H2O', 'h', 'RKT02'],
#         'label': 21.6,
#         'difs': [-8.1, -8.24, -8.34],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -19.038968199810537
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['ch3', 'H2', 'RKT03'],
#         'label': 11.9,
#         'difs': [-7.9, -8.19, -8.46],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 6.674863728577956
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['CH4', 'h', 'RKT03'],
#         'label': 15.0,
#         'difs': [-5.67, -5.95, -6.08],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 4.050776279861587
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['oh', 'CH4', 'RKT04'],
#         'label': 6.3,
#         'difs': [-11.52, -12.07, -12.14],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 0.6311105010035937
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['H2O', 'ch3', 'RKT04'],
#         'label': 19.5,
#         'difs': [-10.57, -11.12, -11.26],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -15.98130172990973
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['h', 'H2', 'RKT06'],
#         'label': 9.7,
#         'difs': [-5.95, -5.97, -6.23],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 4.456859688721782
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['h', 'H2', 'RKT06'],
#         'label': 9.7,
#         'difs': [-5.95, -5.97, -6.23],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 4.456859688721782
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['oh', 'NH3', 'RKT07'],
#         'label': 3.4,
#         'difs': [-15.07, -15.53, -15.65],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -17.318922888336935
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['H2O', 'NH2', 'RKT07'],
#         'label': 13.7,
#         'difs': [-14.56, -15.03, -15.21],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -23.868755791234566
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['hcl', 'ch3', 'RKT08'],
#         'label': 1.8,
#         'difs': [-7.35, -7.94, -8.24],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -15.722289531892704
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['cl', 'CH4', 'RKT08'],
#         'label': 6.8,
#         'difs': [-8.72, -9.3, -9.6],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 5.094560747462392
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['oh', 'C2H6', 'RKT09'],
#         'label': 3.5,
#         'difs': [-12.09, -12.82, -12.88],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -1.594363471577727
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['H2O', 'C2H5', 'RKT09'],
#         'label': 20.4,
#         'difs': [-9.56, -10.46, -10.54],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -13.553802510526694
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['f', 'H2', 'RKT10'],
#         'label': 1.6,
#         'difs': [-13.93, -14.07, -14.1],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -6.021775359920261
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['hf', 'h', 'RKT10'],
#         'label': 33.8,
#         'difs': [-9.18, -9.32, -9.33],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -21.71591619068982
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['O', 'CH4', 'RKT11'],
#         'label': 14.4,
#         'difs': [-14.42, -14.81, -14.86],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 12.089137475599472
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['oh', 'ch3', 'RKT11'],
#         'label': 8.9,
#         'difs': [-9.33, -9.74, -9.89],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -24.73803705192959
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['h', 'PH3', 'RKT12'],
#         'label': 2.9,
#         'difs': [-4.56, -4.77, -5.05],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -3.2093311715980595
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['H2', 'PH2', 'RKT12'],
#         'label': 24.7,
#         'difs': [-6.33, -6.59, -7.06],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 32.48768116546604
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['h', 'oh', 'RKT14'],
#         'label': 10.9,
#         'difs': [-1.82, -1.92, -2.03],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -26.104592485730258
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['H2', 'O', 'RKT14'],
#         'label': 13.2,
#         'difs': [-9.04, -9.14, -9.29],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 13.346669490515175
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['h', 'H2S', 'RKT16'],
#         'label': 3.9,
#         'difs': [-4.99, -5.19, -5.43],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -8.069098391608497
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['H2', 'HS', 'RKT16'],
#         'label': 17.2,
#         'difs': [-7.67, -7.89, -8.33],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 22.504284582890534
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['O', 'hcl', 'RKT17'],
#         'label': 10.4,
#         'difs': [-20.51, -20.58, -20.91],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -11.813729074607755
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['oh', 'cl', 'RKT17'],
#         'label': 9.9,
#         'difs': [-16.78, -16.85, -17.29],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -27.824053322835226
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['NH2', 'ch3', 'RKT18'],
#         'label': 8.9,
#         'difs': [-8.15, -8.66, -8.93],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -17.221074046949596
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['NH', 'CH4', 'RKT18'],
#         'label': 22.0,
#         'difs': [-11.25, -11.76, -11.99],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 15.802278663551085
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['NH2', 'C2H5', 'RKT19'],
#         'label': 9.8,
#         'difs': [-6.8, -7.66, -7.88],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -14.30066357689012
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['NH', 'C2H6', 'RKT19'],
#         'label': 19.4,
#         'difs': [-11.68, -12.37, -12.6],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 14.069715941655122
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['C2H6', 'NH2', 'RKT20'],
#         'label': 11.3,
#         'difs': [-9.76, -10.61, -10.8],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 2.115260914705462
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['C2H5', 'NH3', 'RKT20'],
#         'label': 17.8,
#         'difs': [-7.63, -8.64, -8.81],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -3.294345221328038
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['NH2', 'CH4', 'RKT21'],
#         'label': 13.9,
#         'difs': [-9.42, -10.06, -10.26],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 3.821186055821861
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['NH3', 'ch3', 'RKT21'],
#         'label': 16.9,
#         'difs': [-9.07, -9.71, -9.93],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -6.241393272184914
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['C5H8', 'RKT22'],
#         'label': 39.7,
#         'difs': [-8.5, -8.64, -9.19],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 30.993027747595747
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['C5H8', 'RKT22'],
#         'label': 39.7,
#         'difs': [-8.5, -8.64, -9.19],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 30.993027747595747
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['ed1', 'ts1'],
#         'label': 25.65,
#         'difs': [-9.71, -9.87, -10.04],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 3.82532726155984
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['ed2', 'ts2'],
#         'label': 56.9,
#         'difs': [2.29, 2.05, 2.2],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 58.030956731666905
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['ed3', 'ts3'],
#         'label': 36.53,
#         'difs': [-10.84, -10.51, -10.47],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 4.685297587991459
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['ed4', 'ts4'],
#         'label': 96.17,
#         'difs': [-13.11, -13.64, -14.19],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 104.43902364482047
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['ed5', 'ts5'],
#         'label': 15.94,
#         'difs': [-10.41, -10.57, -11.04],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 4.903622375531103
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['ed6', 'ts6'],
#         'label': 13.64,
#         'difs': [-6.26, -6.58, -7.3],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -9.318282511259008
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['ed7', 'ts7'],
#         'label': 27.49,
#         'difs': [-4.5, -4.81, -6.23],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 23.779714839809618
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['ed8', 'ts8'],
#         'label': 50.24,
#         'difs': [-13.99, -14.04, -15.81],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 28.53357802563306
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['ed9', 'ts9'],
#         'label': 65.84,
#         'difs': [-9.45, -9.46, -9.54],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 63.81580905883887
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['ed10', 'ts10'],
#         'label': 64.93,
#         'difs': [-1.76, -1.71, -1.84],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 83.34812263867121
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['Cyclobutene', 'TS1'],
#         'label': 35.3,
#         'difs': [-3.12, -3.18, -3.37],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 41.17959020309322
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['cis-1,3,5-Hexatriene', 'TS2'],
#         'label': 30.8,
#         'difs': [-5.35, -5.84, -6.51],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 21.008397142901444
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['ortho-xylylene', 'TS3'],
#         'label': 28.1,
#         'difs': [-4.87, -4.91, -4.98],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 24.1808328002183
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['1,3-Pentadiene', 'TS4'],
#         'label': 39.7,
#         'difs': [-8.43, -8.6, -9.15],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 30.82064099007572
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['1,3-Cyclopentadiene', 'TS5'],
#         'label': 28.3,
#         'difs': [-5.54, -5.43, -5.38],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 39.12661308897856
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['1,5-Hexadiene', 'TS6'],
#         'label': 35.8,
#         'difs': [-7.65, -8.53, -9.08],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 20.72543624024448
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['1,3-Butadiene', 'Ethylene', 'TS7'],
#         'label': 22.3,
#         'difs': [-5.84, -8.65, -9.88],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -0.018136988647991226
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['1,3-Cyclopentadiene', 'Ethylene', 'TS8'],
#         'label': 18.0,
#         'difs': [-3.43, -6.42, -7.71],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 0.17983379430386143
#         }
#     },
#     {
#         'stechio_ceofs': [-2, 1],
#         'chemicals': ['1,3-Cyclopentadiene', 'TS11'],
#         'label': 14.5,
#         'difs': [-1.09, -5.58, -6.98],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 1.006601090798901
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['Cis-triscyclopropacyclohexane', 'TS9'],
#         'label': 26.4,
#         'difs': [-6.19, -6.27, -6.03],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 21.22752463697251
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['13r_1', '13_c2h4', '13ts_1a'],
#         'label': 27.6,
#         'difs': [-6.84, -8.12, -8.88],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -18.725043245956993
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['13r_2', '13_c2h4', '13ts_2a'],
#         'label': 20.0,
#         'difs': [-5.43, -6.86, -7.8],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -16.669415102680173
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['13r_3', '13_c2h4', '13ts_3a'],
#         'label': 13.8,
#         'difs': [-2.82, -4.56, -5.42],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -8.370913390791412
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['13r_4', '13_c2h4', '13ts_4a'],
#         'label': 11.8,
#         'difs': [-4.01, -5.61, -6.26],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -11.588992602276244
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['13r_5', '13_c2h4', '13ts_5a'],
#         'label': 6.5,
#         'difs': [-2.28, -3.99, -4.76],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -12.642150490231497
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['13r_6', '13_c2h4', '13ts_6a'],
#         'label': 4.7,
#         'difs': [-1.3, -3.22, -3.96],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -9.306300286188021
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['13r_7', '13_c2h4', '13ts_7a'],
#         'label': 13.1,
#         'difs': [-3.63, -5.66, -6.29],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -18.55985594692308
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['13r_8', '13_c2h4', '13ts_8a'],
#         'label': 5.9,
#         'difs': [-2.43, -4.67, -5.48],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -21.189042654175747
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['13r_9', '13_c2h4', '13ts_9a'],
#         'label': 0.5,
#         'difs': [-1.12, -3.51, -4.13],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -13.575492490557478
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['02r', '00r', '02ts'],
#         'label': 18.1,
#         'difs': [-3.75, -6.72, -8.03],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -1.1778805097653073
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['03r', '00r', '03ts'],
#         'label': 16.6,
#         'difs': [-4.61, -7.5, -9.43],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -4.1090224314046555
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['04r', '00r', '04ts'],
#         'label': 22.9,
#         'difs': [-3.08, -5.66, -6.65],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 3.693929381416114
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['05r', '00r', '06ts'],
#         'label': 27.8,
#         'difs': [-2.23, -4.98, -6.11],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 8.986017583174428
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['07r', '00r', '07ts'],
#         'label': 21.3,
#         'difs': [-2.64, -5.37, -7.38],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 1.7978675821917183
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['07r', '00r', '08ts'],
#         'label': 21.6,
#         'difs': [-2.9, -5.87, -7.59],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 3.2883592452603536
#         }
#     },
#     {
#         'stechio_ceofs': [-1, -1, 1],
#         'chemicals': ['09r', '00r', '09ts'],
#         'label': 31.3,
#         'difs': [-2.16, -5.06, -6.64],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 10.213279539863798
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['ethane_st', 'ethane_ecl'],
#         'label': 2.73,
#         'difs': [-0.28, -0.26, -0.27],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 2.0826773678607564
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['tmethane_60', 'tmethane_0'],
#         'label': 7.01,
#         'difs': [-0.28, -0.13, -0.2],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 5.465706762557755
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['tmethane_60', 'tmethane_120'],
#         'label': 3.46,
#         'difs': [-0.31, -0.08, -0.12],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 3.7528470673547996
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['tmethane_180', 'tmethane_120'],
#         'label': 3.72,
#         'difs': [-0.31, -0.21, -0.23],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 3.384805091269139
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['methanol_st', 'methanol_ecl'],
#         'label': 1.01,
#         'difs': [0.01, 0.02, 0.01],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 1.9543601620502227
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['methylamine_st', 'methylamine_ecl'],
#         'label': 2.28,
#         'difs': [0.36, 0.39, 0.37],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 4.417694740786489
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['h2o2', 'h2o2_trans'],
#         'label': 1.01,
#         'difs': [0.06, 0.06, 0.06],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -0.9465242703628884
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['h2o2', 'h2o2_cis'],
#         'label': 7.17,
#         'difs': [-0.1, -0.08, -0.1],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 8.66731229060037
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['h2s2', 'h2s2_trans'],
#         'label': 5.79,
#         'difs': [0.23, 0.27, 0.23],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 4.050037824710267
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['h2s2', 'h2s2_cis'],
#         'label': 8.03,
#         'difs': [0.23, 0.21, 0.22],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 6.635269356402933
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['n2h4_st1', 'n2h4_ecl1'],
#         'label': 1.62,
#         'difs': [0.13, 0.14, 0.13],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 1.3492174192684567
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['n2h4_st1', 'n2h4_ecl2'],
#         'label': 8.41,
#         'difs': [-0.04, -0.01, -0.05],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 9.799786961289781
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['nh2oh_st1', 'nh2oh_ecl'],
#         'label': 6.91,
#         'difs': [-0.06, -0.03, -0.07],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 8.533044696080752
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['nh2oh_st2', 'nh2oh_ecl'],
#         'label': 2.68,
#         'difs': [0.1, 0.11, 0.1],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 1.8832068407051694
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['acetamide_RC', 'acetamide_TS1'],
#         'label': 17.24,
#         'difs': [1.54, 1.45, 1.49],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 25.994298344202885
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['acetamide_RC', 'acetamide_TS2'],
#         'label': 14.52,
#         'difs': [1.63, 1.58, 1.65],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 23.244293813520876
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['biphenyl', 'biphenyl_TS'],
#         'label': 2.1,
#         'difs': [-0.41, -0.25, -0.4],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 0.058640256448544106
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['bifuran_anti', 'bifuran_TS'],
#         'label': 3.89,
#         'difs': [0.84, 0.94, 0.92],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 3.657304013798881
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['bifuran_syn', 'bifuran_TS'],
#         'label': 2.09,
#         'difs': [1.13, 1.16, 1.23],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 1.6356634889475161
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['bithiophene_anti', 'bithiophene_TS'],
#         'label': 1.78,
#         'difs': [0.46, 0.51, 0.57],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 3.6198251170459526
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['bithiophene_syn', 'bithiophene_TS'],
#         'label': 1.39,
#         'difs': [0.6, 0.48, 0.71],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 3.7388173123748603
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['butadiene_strans', 'butadiene_TS'],
#         'label': 6.3,
#         'difs': [1.19, 1.14, 1.18],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 7.930322534571871
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['butadiene_scis', 'butadiene_TS'],
#         'label': 3.35,
#         'difs': [0.51, 0.54, 0.63],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 5.394233154655352
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['ethylthiourea_180', 'ethylthiourea_TS1'],
#         'label': 10.36,
#         'difs': [0.56, 0.41, 0.52],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 14.41529242675502
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['ethylthiourea_0', 'ethylthiourea_TS1'],
#         'label': 10.24,
#         'difs': [0.79, 0.65, 0.72],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 14.749910571134116
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['ethylthiourea_180', 'ethylthiourea_TS2'],
#         'label': 17.2,
#         'difs': [0.18, -0.01, 0.18],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 21.651736890628815
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['ethylthiourea_0', 'ethylthiourea_TS2'],
#         'label': 17.08,
#         'difs': [0.41, 0.24, 0.38],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 21.98635503500791
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['H2O', 'H2O_TS'],
#         'label': 31.7,
#         'difs': [-1.97, -1.98, -1.97],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 35.71641575932068
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['H2S', 'H2S_TS'],
#         'label': 69.3,
#         'difs': [-3.22, -3.26, -3.21],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 73.11251641360495
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['SO2', 'SO2_TS'],
#         'label': 60.6,
#         'difs': [-5.89, -5.93, -5.86],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 44.65561069905161
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['Ether', 'Ether_TS'],
#         'label': 37.0,
#         'difs': [-3.02, -2.85, -2.77],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 36.898861419685886
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['Thioether', 'Thioether_TS'],
#         'label': 74.2,
#         'difs': [-3.64, -3.26, -3.19],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 79.77931025382152
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['NMe3', 'NMe3_TS'],
#         'label': 9.7,
#         'difs': [-2.08, -1.96, -1.9],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 4.124472812324491
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['NCl3', 'NCl3_TS'],
#         'label': 18.9,
#         'difs': [2.31, 2.26, 2.33],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 27.790609640515168
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['PMe3', 'PMe3_TS'],
#         'label': 43.2,
#         'difs': [-3.99, -3.53, -3.4],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 43.79137588628628
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['PCl3', 'PCl3_TS'],
#         'label': 79.7,
#         'difs': [-1.72, -1.91, -1.49],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 80.62784800669391
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['PH2Ph', 'PH2Ph_TS'],
#         'label': 31.2,
#         'difs': [-2.82, -2.8, -2.73],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 33.718480760938924
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['PPh3', 'PPh3_TS'],
#         'label': 29.3,
#         'difs': [-8.27, -7.3, -7.01],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 26.567711403162722
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['Dibenzocycloheptene', 'Dibenzocycloheptene_TS'],
#         'label': 10.3,
#         'difs': [-1.4, -0.94, -0.85],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 9.929456440846858
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['Tetrahelicene', 'Tetrahelicene_TS'],
#         'label': 4.5,
#         'difs': [-0.49, -0.28, -0.27],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 4.47849779379874
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['Pentahelicene', 'Pentahelicene_TS'],
#         'label': 24.7,
#         'difs': [-2.6, -2.0, -1.9],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 25.605885379393886
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['Hexahelicene', 'Hexahelicene_TS'],
#         'label': 37.6,
#         'difs': [-4.18, -3.25, -2.93],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 39.19028263159461
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['Dibenzocarbazole', 'Dibenzocarbazole_TS'],
#         'label': 4.1,
#         'difs': [-0.76, -0.46, -0.42],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 4.638209594588111
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['Methinecyanine', 'Methinecyanine_TS'],
#         'label': 13.1,
#         'difs': [-3.47, -2.16, -2.26],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 9.500572327974961
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['Corannulene', 'Corannulene_TS'],
#         'label': 11.2,
#         'difs': [-0.71, -0.14, 0.47],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 6.310005981598483
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['BN_Corannulene', 'BN_Corannulene_TS'],
#         'label': 6.2,
#         'difs': [-1.16, -0.82, -0.72],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 1.9346353858623688
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['Sumanene', 'Sumanene_TS'],
#         'label': 21.3,
#         'difs': [-1.88, -1.05, -0.4],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 16.56657896055659
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['Triazasumanene', 'Triazasumanene_TS'],
#         'label': 42.3,
#         'difs': [-2.29, -1.34, -0.52],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 31.0096914761022
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['BN_Sumanene', 'BN_Sumanene_TS'],
#         'label': 27.2,
#         'difs': [-2.76, -1.95, -1.7],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 15.96387795426599
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['Tetrabenzopyracylene', 'Tetrabenzopyracylene_TS'],
#         'label': 8.4,
#         'difs': [-0.97, -0.25, 0.28],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 5.654715059852994
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['Triindenotriphenylene', 'Triindenotriphenylene_TS'],
#         'label': 68.6,
#         'difs': [-2.44, -0.39, 1.17],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 62.1439524504482
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['nh3_2', 'nh3_2_ts'],
#         'label': 59.3,
#         'difs': [-8.63, -8.73, -9.15],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 51.583478529234156
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['nh3_3', 'nh3_3_ts'],
#         'label': 46.9,
#         'difs': [-12.29, -12.51, -13.21],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -3.7385782838943062
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['nh3_4', 'nh3_4_ts'],
#         'label': 48.4,
#         'difs': [-11.99, -12.76, -13.37],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 4.906176608846376
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['h2o_2', 'h2o_2_ts'],
#         'label': 48.6,
#         'difs': [-10.58, -10.44, -10.78],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 14.587666130254961
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['h2o_3', 'h2o_3_ts'],
#         'label': 29.8,
#         'difs': [-11.1, -10.99, -11.41],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -28.451748551362943
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['h2o_4', 'h2o_4_ts'],
#         'label': 26.6,
#         'difs': [-12.01, -12.2, -12.53],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -43.01940599810067
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['h2o_5', 'h2o_5_ts'],
#         'label': 30.1,
#         'difs': [-14.35, -14.77, -15.08],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -54.052621445489144
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['h2o_6', 'h2o_6_ts'],
#         'label': 35.1,
#         'difs': [-16.87, -17.28, -17.7],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -64.36917887733398
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['hf_2', 'hf_2_ts'],
#         'label': 42.3,
#         'difs': [-10.73, -10.52, -10.79],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -0.7664940987863961
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['hf_3', 'hf_3_ts'],
#         'label': 20.7,
#         'difs': [-9.96, -9.72, -10.01],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -38.406586156385636
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['hf_4', 'hf_4_ts'],
#         'label': 14.7,
#         'difs': [-9.39, -9.4, -9.54],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -44.16642565438778
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['hf_5', 'hf_5_ts'],
#         'label': 14.6,
#         'difs': [-10.27, -10.44, -10.52],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -49.95303589765933
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1],
#         'chemicals': ['hf_6', 'hf_6_ts'],
#         'label': 16.6,
#         'difs': [-11.9, -12.12, -12.21],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -58.14150458160427
# ...
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['f2s-ch2', 'f2s', 'ch2'],
#         'label': 91.14,
#         'difs': [5.11, 5.64, 6.37],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 82.48748270484204
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['h2s-cbh22', 'h2s', 'cbh22'],
#         'label': 20.96,
#         'difs': [-4.61, -3.35, -2.29],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 13.234068504447729
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['h2s-ch2', 'h2s', 'ch2'],
#         'label': 36.4,
#         'difs': [6.64, 7.01, 7.82],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 24.97527372716585
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['me2s-cbh22', 'me2s', 'cbh22'],
#         'label': 38.99,
#         'difs': [-7.82, -5.32, -3.98],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 32.759037673552704
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['me2s-ch2', 'me2s', 'ch2'],
#         'label': 51.74,
#         'difs': [4.11, 5.2, 6.13],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 44.56520833223868
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['nf3-cbh22', 'nf3', 'cbh22'],
#         'label': 12.31,
#         'difs': [1.84, 3.45, 3.89],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 10.832205753971785
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['nf3-ch2', 'nf3', 'ch2'],
#         'label': 53.73,
#         'difs': [9.97, 10.79, 11.05],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 47.02644273732269
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['nh3-cbh22', 'nh3', 'cbh22'],
#         'label': 32.58,
#         'difs': [-5.34, -4.13, -3.41],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 54.38798169017797
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['nh3-ch2', 'nh3', 'ch2'],
#         'label': 28.87,
#         'difs': [2.83, 3.23, 3.84],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 25.481850971178407
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['nme3-cbh22', 'nme3', 'cbh22'],
#         'label': 42.11,
#         'difs': [-12.78, -9.45, -8.07],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 56.436741298998
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['nme3-ch2', 'nme3', 'ch2'],
#         'label': 42.81,
#         'difs': [-2.62, -0.92, 0.04],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 27.62671657872031
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['pf3-cbh22', 'pf3', 'cbh22'],
#         'label': 52.28,
#         'difs': [-12.55, -10.92, -9.73],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 40.205403827604265
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['pf3-ch2', 'pf3', 'ch2'],
#         'label': 76.37,
#         'difs': [-1.77, -1.04, -0.31],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 71.84607274880797
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['ph3-cbh22', 'ph3', 'cbh22'],
#         'label': 44.8,
#         'difs': [-8.72, -7.4, -6.13],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 33.23642156224562
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['ph3-ch2', 'ph3', 'ch2'],
#         'label': 60.11,
#         'difs': [1.9, 2.4, 3.24],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 46.64749373370498
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['pme3-cbh22', 'pme3', 'cbh22'],
#         'label': 66.59,
#         'difs': [-11.78, -8.84, -7.28],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 59.23448052637275
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['pme3-ch2', 'pme3', 'ch2'],
#         'label': 78.0,
#         'difs': [-0.42, 0.88, 1.9],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 69.08280085530458
#         }
#     },
#     {
#         'stechio_ceofs': [2, -1],
#         'chemicals': ['AM2', 'AD2'],
#         'label': 1.34,
#         'difs': [-1.16, 0.32, 0.17],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 1.3014792455557809
#         }
#     },
#     {
#         'stechio_ceofs': [2, -1],
#         'chemicals': ['AM3', 'AD3'],
#         'label': 1.99,
#         'difs': [-1.86, 0.43, 0.22],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 1.997745289674742
#         }
#     },
#     {
#         'stechio_ceofs': [2, -1],
#         'chemicals': ['AM4', 'AD4'],
#         'label': 2.89,
#         'difs': [-2.84, 0.54, 0.23],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 3.0208652992396625
#         }
#     },
#     {
#         'stechio_ceofs': [2, -1],
#         'chemicals': ['AM5', 'AD5'],
#         'label': 3.78,
#         'difs': [-3.79, 0.61, 0.21],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 3.885301256384736
#         }
#     },
#     {
#         'stechio_ceofs': [2, -1],
#         'chemicals': ['AM6', 'AD6'],
#         'label': 4.6,
#         'difs': [-4.74, 0.76, 0.29],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 4.872555493087576
#         }
#     },
#     {
#         'stechio_ceofs': [2, -1],
#         'chemicals': ['AM7', 'AD7'],
#         'label': 5.55,
#         'difs': [-5.87, 0.63, 0.13],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 5.542023201603101
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['1', '1A', '1B'],
#         'label': -17.79,
#         'difs': [-0.43, -0.77, -0.75],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -63.76520736867086
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['2', '2A', '2B'],
#         'label': -32.5,
#         'difs': [-0.03, -0.25, -0.29],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -93.62641729880384
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['3', '3A', '3B'],
#         'label': -65.68,
#         'difs': [1.93, 1.86, 1.76],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -127.11510305231792
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['4', '4A', '4B'],
#         'label': -8.98,
#         'difs': [-0.07, -0.54, -0.64],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -13.133114018865486
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['5', '5A', '5B'],
#         'label': -15.61,
#         'difs': [-0.39, -0.74, -0.91],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -22.62961087709496
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['6', '6A', '6B'],
#         'label': -25.52,
#         'difs': [-0.98, -1.14, -1.38],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -33.53584775477915
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['7', '7A', '7B'],
#         'label': -14.35,
#         'difs': [-1.83, -2.25, -2.61],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -29.117987459405974
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['8', '8A', '8B'],
#         'label': -41.79,
#         'difs': [-2.08, -2.27, -2.8],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -64.92479638122633
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['9', '9A', '9B'],
#         'label': -17.03,
#         'difs': [-0.76, -1.21, -1.23],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -51.13360785948947
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['10', '10A', '10B'],
#         'label': -37.31,
#         'difs': [-0.52, -0.83, -0.94],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -88.15888553435559
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['11', '11A', '11B'],
#         'label': -7.97,
#         'difs': [0.1, -0.36, -0.44],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -12.727258370253107
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['12', '12A', '12B'],
#         'label': -14.13,
#         'difs': [-0.25, -0.69, -0.78],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -22.838551720933687
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['13', '13A', '13B'],
#         'label': -26.01,
#         'difs': [-1.56, -1.94, -2.06],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -38.10191720767973
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['14', '14A', '14B'],
#         'label': -11.07,
#         'difs': [-0.65, -1.18, -1.39],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -22.27518294977015
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['15', '15A', '15B'],
#         'label': -8.62,
#         'difs': [-0.44, -0.96, -1.12],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -13.078519466198511
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['16', '16A', '16B'],
#         'label': -15.73,
#         'difs': [-0.89, -1.3, -1.54],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -23.119669991834375
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['17', '17A', '17B'],
#         'label': -26.24,
#         'difs': [-1.52, -1.79, -2.03],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -34.568552020435774
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['18', '18A', '18B'],
#         'label': -12.8,
#         'difs': [1.31, -0.25, -0.09],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -18.985956059499994
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['19', '19A', '19B'],
#         'label': -20.65,
#         'difs': [0.73, -0.49, -0.46],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -34.58606101373501
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['20', '20A', '20B'],
#         'label': -21.03,
#         'difs': [0.75, -0.13, -0.17],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -33.103774329320736
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['21', '21A', '21B'],
#         'label': -31.4,
#         'difs': [-0.21, -0.67, -0.75],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -44.87502512310127
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['1O', '1O_A', '1O_B'],
#         'label': 5.37,
#         'difs': [0.88, 1.27, 1.32],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 8.830713378503814
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['2O', '2O_A', '2O_B'],
#         'label': 6.047,
#         'difs': [0.87, 1.62, 1.64],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 8.564937469617599
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['3O', '3O_A', '3O_B'],
#         'label': 2.421,
#         'difs': [0.51, 0.84, 1.01],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 3.1132263350024476
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['4O', '4O_A', '4O_B'],
#         'label': 9.967,
#         'difs': [0.53, 1.82, 1.77],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 15.36854787661559
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['1N', '1N_A', '1N_B'],
#         'label': 2.357,
#         'difs': [0.47, 0.86, 0.9],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 5.079852725435985
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['2N', '2N_A', '2N_B'],
#         'label': 3.021,
#         'difs': [0.18, 0.88, 0.88],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 4.5592075926541415
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['3N', '3N_A', '3N_B'],
#         'label': 1.205,
#         'difs': [0.12, 0.49, 0.62],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 1.8896614578899276
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['4N', '4N_A', '4N_B'],
#         'label': 4.177,
#         'difs': [-0.12, 1.15, 1.11],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 6.6778385878192665
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['1CL', '1CL_A', '1CL_B'],
#         'label': 7.839,
#         'difs': [3.62, 4.11, 4.27],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 20.325913963945183
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['2CL', '2CL_A', '2CL_B'],
#         'label': 10.483,
#         'difs': [3.27, 4.33, 4.51],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 21.6721441331473
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['3CL', '3CL_A', '3CL_B'],
#         'label': 3.241,
#         'difs': [0.96, 1.41, 1.64],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 5.782391038703718
#         }
#     },
#     {
#         'stechio_ceofs': [-1, 1, 1],
#         'chemicals': ['4CL', '4CL_A', '4CL_B'],
#         'label': 16.296,
#         'difs': [1.5, 3.1, 3.22],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': 30.41270404770241
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['22', '22A', '22B'],
#         'label': -34.43,
#         'difs': [-0.62, -0.66, -1.05],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -61.93479295772542
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['23', '23A', '23B'],
#         'label': -23.83,
#         'difs': [-0.42, -0.6, -0.89],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -44.32277849601005
#         }
#     },
#     {
#         'stechio_ceofs': [1, -1, -1],
#         'chemicals': ['24', '24A', '24B'],
#         'label': -17.83,
#         'difs': [0.18, -0.1, -0.33],
#         'PBE-MINIX_energydiff': {
#             'PBE-MINIX_FINAL_SINGLE_POINT_ENERGY': -24.692481901960107
#         }
#     },
#     # ...and 505 more elements
# ]
# =======  END  =======

# %%
allfeatures = set()

metricsets = ["SMALL"]
includeFull = True

for setname in fullsetnames:
    for val in allvalues_perset[setname]:
        for k in val:
            if k.find("energydiff") != -1:
                for f in val[k]:
                    allfeatures.add(f)
for setname in fullsetnames:
    models_results[setname].inside_methods_rmse = []
    models_results[setname].inside_methods_r2 = []
    models_results[setname].our_methods_rmse = {}
    models_results[setname].our_methods_r2 = {}
    
    models_results[setname].bestinsidemethod_rmse = float("inf")
    models_results[setname].bestinsidemethod = ""
    models_results[setname].bestourmethod_rmse = float("inf")
    models_results[setname].bestourmethod = ""
    models_results[setname].our_methods_name = []

    for methodid in range(howmanydifs):
        y_pred = []
        labels = []
        for val in allvalues_perset[setname]:
            y_pred.append(val["label"] + val["difs"][methodid])
            labels.append(val["label"])
        
        r2 = r2_score(labels, y_pred)
        rmse = mean_squared_error(labels, y_pred, squared=False)
        models_results[setname].inside_methods_rmse.append(rmse)
        models_results[setname].inside_methods_r2.append(r2)

        if rmse < models_results[setname].bestinsidemethod_rmse:
            models_results[setname].bestinsidemethod_rmse = rmse
            #models_results[setname].bestinsidemethod = str(methodid)
            models_results[setname].bestinsidemethod = insidemethodslist[methodid]
            models_results[setname].y_pred_bestinsidemethod = y_pred

    for j, method in enumerate(methods):
        y_pred = []
        labels = []
        for val in allvalues_perset[setname]:
            y_pred.append(val[method + "_energydiff"][method+"_FINAL_SINGLE_POINT_ENERGY"])
            labels.append(val["label"])
        
        r2 = r2_score(labels, y_pred)
        rmse = mean_squared_error(labels, y_pred, squared=False)

        models_results[setname].our_methods_rmse[method] = rmse
        models_results[setname].our_methods_r2[method] = r2
        models_results[setname].our_methods_name.append(method)

        if rmse < models_results[setname].bestourmethod_rmse:
            models_results[setname].bestourmethod_rmse = rmse
            models_results[setname].bestourmethod = method
            models_results[setname].y_pred_bestourmethod = y_pred


######################################################################################
# WTMAD2 Calculation for reference methods (wtmad_ref):

wtmad2_ref = commonutils.wtmad_ref(fullsetnames, metricsets, howmanydifs,allvalues_perset, includeFull)

print("WTMAD-2 for inside methods", "\n")
print(wtmad2_ref, '\n')

# WTMAD2 Calculation for our methods (wtmad):

wtmad2 = commonutils.wtmad(fullsetnames, metricsets, methods,allvalues_perset, includeFull)

print("WTMAD-2 for our methods", "\n")
print(wtmad2, "\n")


######################################################################################


print("Results for inside and our methods")
print("%40s"% "Dataset", " , ", \
      "Best inside method", " , ", \
      "RMSE", " , ", \
      "Best our method", " , ", \
      "RMSE")
for setname in fullsetnames:
    print("%40s"%setname, " , ", \
        models_results[setname].bestinsidemethod , " , ",\
        "%7.3f"%models_results[setname].bestinsidemethod_rmse, " , ", \
        "%5s"%models_results[setname].bestourmethod , " , ", \
        "%7.3f"%models_results[setname].bestourmethod_rmse)
# Out:
# WTMAD-2 for inside methods
#
#   Superset  WTMAD-2_0  WTMAD-2_1  WTMAD-2_2
# 0    SMALL      13.26      13.01      13.31
# 1     Full      13.26      13.01      13.31
#
# WTMAD-2 for our methods
#
#   Superset  WTMAD-2_PBE-MINIX
# 0    SMALL              61.15
# 1     Full              61.15
#
# Results for inside and our methods
#                                  Dataset  ,  Best inside method  ,  RMSE  ,  Best our method  ,  RMSE
#                                  BARRIER  ,  W  ,    8.201  ,  PBE-MINIX  ,   28.824
#                             BARRIER_BH76  ,  W  ,   10.387  ,  PBE-MINIX  ,   32.138
#                          BARRIER_BHDIV10  ,  W  ,    9.191  ,  PBE-MINIX  ,   17.428
#                           BARRIER_BHPERI  ,  W  ,    4.407  ,  PBE-MINIX  ,   20.851
#                          BARRIER_BHROT27  ,  D3(0)  ,    0.611  ,  PBE-MINIX  ,    3.211
#                            BARRIER_INV24  ,  D3(BJ)  ,    2.658  ,  PBE-MINIX  ,    5.864
#                             BARRIER_PX13  ,  W  ,   11.730  ,  PBE-MINIX  ,   61.679
#                           BARRIER_WCPT18  ,  W  ,    8.999  ,  PBE-MINIX  ,   31.430
#                                    INTRA  ,  D3(BJ)  ,    0.873  ,  PBE-MINIX  ,    4.985
#                              INTRA_ACONF  ,  D3(BJ)  ,    0.090  ,  PBE-MINIX  ,    1.254
#                          INTRA_Amino20x4  ,  D3(0)  ,    0.375  ,  PBE-MINIX  ,    3.158
#                          INTRA_BUT14DIOL  ,  W  ,    0.349  ,  PBE-MINIX  ,    5.447
#                              INTRA_ICONF  ,  D3(BJ)  ,    0.450  ,  PBE-MINIX  ,    1.495
#                              INTRA_IDISP  ,  D3(BJ)  ,    4.154  ,  PBE-MINIX  ,   11.850
#                              INTRA_MCONF  ,  D3(0)  ,    0.480  ,  PBE-MINIX  ,    2.422
#                            INTRA_PCONF21  ,  D3(0)  ,    1.286  ,  PBE-MINIX  ,    5.079
#                              INTRA_SCONF  ,  W  ,    0.472  ,  PBE-MINIX  ,   12.358
#                              INTRA_UPU23  ,  D3(0)  ,    0.563  ,  PBE-MINIX  ,    3.432
#                                    SMALL  ,  W  ,   12.191  ,  PBE-MINIX  ,   42.495
#                              SMALL_AL2X6  ,  D3(BJ)  ,    2.505  ,  PBE-MINIX  ,   14.375
#                               SMALL_ALK8  ,  W  ,    3.553  ,  PBE-MINIX  ,   13.792
#                           SMALL_ALKBDE10  ,  W  ,   10.191  ,  PBE-MINIX  ,   70.527
#                             SMALL_BH76RC  ,  W  ,    6.040  ,  PBE-MINIX  ,   31.359
#                               SMALL_DC13  ,  D3(0)  ,   12.167  ,  PBE-MINIX  ,   32.294
#                            SMALL_DIPCS10  ,  D3(BJ)  ,    5.986  ,  PBE-MINIX  ,   39.667
#                               SMALL_FH51  ,  D3(0)  ,    4.379  ,  PBE-MINIX  ,   33.394
#                              SMALL_G21EA  ,  D3(BJ)  ,    4.107  ,  PBE-MINIX  ,   83.782
#                              SMALL_G21IP  ,  W  ,    4.835  ,  PBE-MINIX  ,   21.426
#                               SMALL_G2RC  ,  W  ,    7.746  ,  PBE-MINIX  ,   34.125
#                          SMALL_HEAVYSB11  ,  D3(0)  ,    3.921  ,  PBE-MINIX  ,    3.956
#                              SMALL_NBPRC  ,  D3(0)  ,    2.798  ,  PBE-MINIX  ,   19.861
#                               SMALL_PA26  ,  W  ,    2.673  ,  PBE-MINIX  ,   15.199
#                               SMALL_RC21  ,  W  ,    6.400  ,  PBE-MINIX  ,   33.834
#                             SMALL_SIE4x4  ,  W  ,   26.188  ,  PBE-MINIX  ,   41.597
#                             SMALL_TAUT15  ,  D3(0)  ,    2.185  ,  PBE-MINIX  ,    9.807
#                              SMALL_W4-11  ,  W  ,   18.505  ,  PBE-MINIX  ,   53.358
#                             SMALL_YBDE18  ,  D3(BJ)  ,    5.767  ,  PBE-MINIX  ,   11.003
#                                    INTER  ,  W  ,    2.286  ,  PBE-MINIX  ,   39.094
#                              INTER_ADIM6  ,  D3(BJ)  ,    0.214  ,  PBE-MINIX  ,    0.132
#                              INTER_AHB21  ,  W  ,    1.038  ,  PBE-MINIX  ,   27.019
#                           INTER_CARBHB12  ,  W  ,    1.563  ,  PBE-MINIX  ,    6.778
#                               INTER_CHB6  ,  D3(0)  ,    0.823  ,  PBE-MINIX  ,   15.086
#                              INTER_HAL59  ,  D3(0)  ,    1.639  ,  PBE-MINIX  ,    9.366
#                            INTER_HEAVY28  ,  D3(0)  ,    0.372  ,  PBE-MINIX  ,    4.131
#                               INTER_IL16  ,  D3(0)  ,    0.657  ,  PBE-MINIX  ,   19.748
#                            INTER_PNICO23  ,  W  ,    1.298  ,  PBE-MINIX  ,    5.968
#                               INTER_RG18  ,  D3(BJ)  ,    0.314  ,  PBE-MINIX  ,    0.279
#                                INTER_S22  ,  D3(BJ)  ,    0.634  ,  PBE-MINIX  ,    5.586
#                                INTER_S66  ,  D3(BJ)  ,    0.525  ,  PBE-MINIX  ,    3.654
#                            INTER_WATER27  ,  W  ,    3.884  ,  PBE-MINIX  ,  126.651
#                                    LARGE  ,  D3(0)  ,   12.567  ,  PBE-MINIX  ,   40.619
#                              LARGE_BSR36  ,  D3(BJ)  ,    3.785  ,  PBE-MINIX  ,    2.988
#                             LARGE_C60ISO  ,  D3(BJ)  ,   12.799  ,  PBE-MINIX  ,    2.620
#                             LARGE_CDIE20  ,  D3(BJ)  ,    1.781  ,  PBE-MINIX  ,    1.800
#                               LARGE_DARC  ,  D3(BJ)  ,    3.649  ,  PBE-MINIX  ,   27.202
#                              LARGE_ISO34  ,  D3(BJ)  ,    2.081  ,  PBE-MINIX  ,   11.429
#                             LARGE_ISOL24  ,  D3(BJ)  ,    6.365  ,  PBE-MINIX  ,   24.427
#                            LARGE_MB16-43  ,  D3(0)  ,   27.916  ,  PBE-MINIX  ,   92.244
#                              LARGE_PArel  ,  D3(BJ)  ,    2.525  ,  PBE-MINIX  ,   12.788
#                              LARGE_RSE43  ,  D3(0)  ,    3.188  ,  PBE-MINIX  ,    7.156
#                                     Full  ,  D3(0)  ,    9.227  ,  PBE-MINIX  ,   35.420

# %%
setname = "Full"
models_results[setname].fulldescriptors = []
models_results[setname].labels = []
for idx, val in enumerate(allvalues_perset[setname]):
    models_results[setname].fulldescriptors.append({})
    for method in methods:
        models_results[setname].fulldescriptors[idx].update(val[method+"_energydiff"])

    models_results[setname].labels.append(val["label"])

X, Y, features_names = \
    commonutils.build_XY_matrix (models_results[setname].fulldescriptors, \
                                 models_results[setname].labels)

df = pd.DataFrame(X, columns=features_names)

corr = df.corr().abs()
top_correlation = {}
for k in corr.columns:
    top_correlation[k] = []
    print(k, " ")
    for idx, v in enumerate(corr[k]):
        if v > CORRCUT and corr.index[idx] != k:
            top_correlation[k].append((corr.index[idx], v))
            print(" %40s %4.2f"%(corr.index[idx], v))

# %%
featurestorms = set()
for tc in top_correlation:
    if tc not in featurestorms:
        for correlated in top_correlation[tc]:
            featurestorms.add(correlated[0])

print ("Features that are correlated with others and to remove")  
for idx, k in enumerate(featurestorms):
    print(idx+1 , " ", k)

# %%
print ("Features TO USE")
idx = 1
for f in allfeatures:
    if f not in featurestorms:
        print(idx, f) 
        idx += 1

# %%
featurestorm = list(featurestorms)

for setname in fullsetnames:
    commonutils.remove_features_fromset(allvalues_perset[setname], \
                                            list(featurestorm), \
                                            methods)

for setname in fullsetnames:
    models_results[setname].fulldescriptors = []
    models_results[setname].labels = []
    for idx, val in enumerate(allvalues_perset[setname]):
        models_results[setname].fulldescriptors.append({})
        for method in methods:
            if method+"_energydiff" in val:
                models_results[setname].fulldescriptors[idx].update(\
                    val[method+"_energydiff"])

        models_results[setname].labels.append(val["label"])

setname = "Full"
X, Y, features_names = \
    commonutils.build_XY_matrix (models_results[setname].fulldescriptors, \
                                 models_results[setname].labels)

df = pd.DataFrame(X, columns=features_names)

# %%
import seaborn as sns
# %matplotlib inline
print("Correlation matrix")
plt.rcParams['figure.figsize'] = 10,10
sns.set(font_scale=2)
sns.heatmap(df.corr().abs(), annot=True)
#print(df.corr().abs())
#sns.heatmap(df, annot=True)

# %%
perc_split = 0.2
for setname in fullsetnames:
       print("Running PLS for dataset: ", setname)

       X, Y, features_names = \
          commonutils.build_XY_matrix (models_results[setname].fulldescriptors, \
                  models_results[setname].labels)
       maxcomp = X.shape[1]
       ncomps, rmses_test, rmses_train, r2s_test, r2s_train = \
              models.pls_model (perc_split, X, Y, \
              ncomp_start = 1, ncomp_max = maxcomp)
       r2max_comps = np.argmax(r2s_test)+1
       rmsemin_comps = np.argmin(rmses_test)+1
       compstouse = min(rmsemin_comps, r2max_comps)
       rmse_train, rmse_test, r2_train, \
          r2_test, rmse_full, r2_full , \
          models_results[setname].plsmodel, \
          X_train, X_test, y_train, y_test  = \
                  models.pls_model (perc_split, X, Y, False, compstouse)
       
       models_results[setname].y_pred = \
          models_results[setname].plsmodel.predict(X)

# %%
print(" Dim , %40s"% "Dataset", " , ", \
      "Best inside method RMSE", " , ", \
      "Best our method RMSE", " , ", \
      "RMSE , R2 , " + \
      "RMSE (superset) , R2 (superset) ," + \
      "RMSE (Full) , R2 (Full) ")
pls_model_full = models_results["Full"].plsmodel
X, Y, features_names = \
    commonutils.build_XY_matrix (models_results["Full"].fulldescriptors, \
                                    models_results["Full"].labels)
y_pred = pls_model_full.predict(X)
rmse = mean_squared_error(Y, y_pred, squared=False)
r2 = r2_score(Y, y_pred)
print("%4d , %40s"%(len(models_results["Full"].labels), "Full"), " , ", \
    "%7.3f"%models_results["Full"].bestinsidemethod_rmse, " , ", \
    "%7.3f"%models_results["Full"].bestourmethod_rmse, " , ", \
    "%7.3f"%rmse, " , ", \
    "%7.3f"%r2, " , ", \
    "%7.3f"%rmse, " , ", \
    "%7.3f"%r2, " , ", \
    "%7.3f"%rmse, " , ", \
    "%7.3f"%r2)

for ssetname in supersetnames:
    pls_model_ssetname = models_results[ssetname].plsmodel
    X, Y, features_names = \
        commonutils.build_XY_matrix (models_results[ssetname].fulldescriptors, \
                                    models_results[ssetname].labels)
    y_pred = pls_model_ssetname.predict(X)
    rmse = mean_squared_error(Y, y_pred, squared=False)
    r2 = r2_score(Y, y_pred)    

    y_pred_full = pls_model_full.predict(X) 
    rmse_full = mean_squared_error(Y, y_pred_full, squared=False)
    r2_full = r2_score(Y, y_pred_full)

    print("%4d , %40s"%(len(models_results[ssetname].labels), ssetname), " , ", \
        "%7.3f"%models_results[ssetname].bestinsidemethod_rmse, " , ", \
        "%7.3f"%models_results[ssetname].bestourmethod_rmse, " , ", \
        "%7.3f"%rmse, " , ", \
        "%7.3f"%r2, " , ", \
        "%7.3f"%rmse, " , ", \
        "%7.3f"%r2, " , ", \
        "%7.3f"%rmse_full, " , ", \
        "%7.3f"%r2_full)
    
    for isetname in supersetnames[ssetname]:
        setname = ssetname + "_" + isetname
        pls_model = models_results[setname].plsmodel    
        X, Y, features_names = \
            commonutils.build_XY_matrix (models_results[setname].fulldescriptors, \
                                    models_results[setname].labels)
        y_pred = pls_model.predict(X)
        rmse = mean_squared_error(Y, y_pred, squared=False)
        r2 = r2_score(Y, y_pred)

        y_pred_ssetname = pls_model_ssetname.predict(X)
        rmse_ssetname = mean_squared_error(Y, y_pred_ssetname, squared=False)
        r2_ssetname = r2_score(Y, y_pred_ssetname)

        y_pred_full = pls_model_full.predict(X)
        rmse_full = mean_squared_error(Y, y_pred_full, squared=False)
        r2_full = r2_score(Y, y_pred_full)

        print("%4d , %40s"%(len(models_results[setname].labels), setname), " , ", \
            "%7.3f"%models_results[setname].bestinsidemethod_rmse, " , ", \
            "%7.3f"%models_results[setname].bestourmethod_rmse, " , ", \
            "%7.3f"%rmse, " , ", \
            "%7.3f"%r2, " , ", \
            "%7.3f"%rmse_ssetname, " , ", \
            "%7.3f"%r2_ssetname, " , ", \
            "%7.3f"%rmse_full, " , ", \
            "%7.3f"%r2_full)

# %%
# test scaling Y
X, Y, features_names = \
    commonutils.build_XY_matrix (models_results["Full"].fulldescriptors, \
                                    models_results["Full"].labels)
scalery = preprocessing.StandardScaler().fit(Y.reshape(-1, 1))   
Y_s = scalery.transform(Y.reshape(-1, 1))
scalerx = preprocessing.StandardScaler().fit(X)
X_s = scalerx.transform(X)
  
perc_split = 0.2
maxcomp = X_s.shape[1]

ncomps, rmses_test, rmses_train, r2s_test, r2s_train = \
              models.pls_model (perc_split, X_s, Y_s, \
              ncomp_start = 1, ncomp_max = maxcomp)
r2max_comps = np.argmax(r2s_test)+1
rmsemin_comps = np.argmin(rmses_test)+1
compstouse = min(rmsemin_comps, r2max_comps)
rmse_train, rmse_test, r2_train, \
    r2_test, rmse_full, r2_full , \
    plsmodel, \
    X_train, X_test, y_train, y_test  = \
        models.pls_model (perc_split, X_s, Y_s, False, compstouse)
       
y_pred_s = plsmodel.predict(X_s)
y_pred = scalery.inverse_transform(y_pred_s)

rmse = mean_squared_error(Y, y_pred, squared=False)
r2 = r2_score(Y, y_pred)

print("Scaling Y")
print("RMSE %7.3f"%rmse, " , ", "R2 %7.3f"%r2)

# %%
setname = "Full"
pls_model_full = models_results[setname].plsmodel

for setname in fullsetnames:

    pls_model = models_results[setname].plsmodel
    X, Y, features_names = \
        commonutils.build_XY_matrix (models_results[setname].fulldescriptors, \
                                    models_results[setname].labels)
    y_pred_full = pls_model_full.predict(X)
    rmse_full = mean_squared_error(Y, y_pred_full, squared=False)
    r2_full = r2_score(Y, y_pred_full)

    y_pred = pls_model.predict(X)
    rmse = mean_squared_error(Y, y_pred, squared=False)
    r2 = r2_score(Y, y_pred)

    print(setname)
    print("RMSE %7.3f"%rmse, " R2 %7.3f"%r2)
    print("RMSE (Full) %7.3f"%rmse_full, " R2 (Full) %7.3f"%r2_full)
    plt.clf()
    fig, ax = plt.subplots()
    ax.scatter(Y, y_pred, c='b', s=50, label='PLS Model')
    ax.scatter(Y, y_pred_full, c='black', s=50, label='PLS Full Model')
    ax.scatter(Y, models_results[setname].y_pred_bestinsidemethod, \
                c='r', s=50, label=f"ref-PBE-{models_results[setname].bestinsidemethod}")
    ax.scatter(Y, models_results[setname].y_pred_bestourmethod, \
               c='g', s=50, label=f"{models_results[setname].bestourmethod}")
    lims = [
        np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
        np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
    ]
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.legend(loc="upper left")
    plt.title(f"PLS {setname} model")
    plt.show()
